# %%
#for an interactive plot
# %matplotlib notebook

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %%
#Display the data frame with city names
df_cities= pd.DataFrame({"City": cities})

df_cities
# Out:
#              City
# 0           bluff
# 1          sivaki
# 2        souillac
# 3      chokurdakh
# 4       taolanaro
# ..            ...
# 623         avera
# 624     chukhloma
# 625  port lincoln
# 626  christchurch
# 627         salym
#
# [628 rows x 1 columns]

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Initialize empty list to store weather data received from weather api for each of the cities above
new_cities = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind = []

# %%
#Initialize counter for print log sets of 50 cities
record_counter = 0
set_counter = 1

# URL for API Call and api key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + api_key 

print('Beginning Data Retrieval')
print('------------------------')

for city in cities:
    #API request for the above series of cities
    query_url = url + "&q=" + city
    # Convert to json
    response = requests.get(query_url).json()
    
    if record_counter < 50:
        record_counter += 1
        
    else:
        set_counter += 1
        record_counter = 1
    
    #Include a print log of each city as it's being processed (with the city number and city name and the complete url)
    print('Processing record {} of set {} | {}'.format(record_counter, set_counter, city.capitalize()))
    print(query_url)
    
    
    #try-except block for error free execution when city not found
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        new_cities.append(city)
        
    except:
        print("City not found!")
        pass

print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 1 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=bluff
# Processing record 2 of set 1 | Sivaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=sivaki
# Processing record 3 of set 1 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=souillac
# Processing record 4 of set 1 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=chokurdakh
# Processing record 5 of set 1 | Taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=taolanaro
# City not found!
# Processing record 6 of set 1 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=busselton
# Processing record 7 of set 1 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=faanui
# Processing record 8 of set 1 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=yulara
# Processing record 9 of set 1 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=ancud
# Processing record 10 of set 1 | Saskatoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=saskatoon
# Processing record 11 of set 1 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=ushuaia
# Processing record 12 of set 1 | Aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=aykhal
# Processing record 13 of set 1 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=hobyo
# Processing record 14 of set 1 | Los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=los llanos de aridane
# Processing record 15 of set 1 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=hobart
# Processing record 16 of set 1 | Liverpool
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=liverpool
# Processing record 17 of set 1 | Belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=belushya guba
# City not found!
# Processing record 18 of set 1 | Ust-maya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=ust-maya
# Processing record 19 of set 1 | Yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=yar-sale
# Processing record 20 of set 1 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=vaini
# Processing record 21 of set 1 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=saskylakh
# Processing record 22 of set 1 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=hilo
# Processing record 23 of set 1 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=hermanus
# Processing record 24 of set 1 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=kapaa
# Processing record 25 of set 1 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=rikitea
# Processing record 26 of set 1 | Cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=cape town
# Processing record 27 of set 1 | Ayr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=ayr
# Processing record 28 of set 1 | Porto santo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=porto santo
# City not found!
# Processing record 29 of set 1 | Acarau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=acarau
# City not found!
# Processing record 30 of set 1 | Crab hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=crab hill
# City not found!
# Processing record 31 of set 1 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=atuona
# Processing record 32 of set 1 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=albany
# Processing record 33 of set 1 | Shakiso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=shakiso
# Processing record 34 of set 1 | Mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=mar del plata
# Processing record 35 of set 1 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=avarua
# Processing record 36 of set 1 | Storforshei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=storforshei
# Processing record 37 of set 1 | Savannah bight
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=savannah bight
# Processing record 38 of set 1 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=kavieng
# Processing record 39 of set 1 | Sept-iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=sept-iles
# Processing record 40 of set 1 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=mahebourg
# Processing record 41 of set 1 | Hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=hirara
# Processing record 42 of set 1 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=esperance
# Processing record 43 of set 1 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=tuatapere
# Processing record 44 of set 1 | Tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=tsihombe
# City not found!
# Processing record 45 of set 1 | Alta floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=alta floresta
# Processing record 46 of set 1 | Mackenzie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=mackenzie
# Processing record 47 of set 1 | Koster
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=koster
# Processing record 48 of set 1 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=nikolskoye
# Processing record 49 of set 1 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=pevek
# Processing record 50 of set 1 | Toora-khem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=toora-khem
# Processing record 1 of set 2 | Vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=vaitupu
# City not found!
# Processing record 2 of set 2 | Atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=atar
# Processing record 3 of set 2 | Port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=port elizabeth
# Processing record 4 of set 2 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=hamilton
# Processing record 5 of set 2 | Abu dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=abu dhabi
# Processing record 6 of set 2 | Port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=port alfred
# Processing record 7 of set 2 | Norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=norman wells
# Processing record 8 of set 2 | New norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=new norfolk
# Processing record 9 of set 2 | Maryborough
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=maryborough
# Processing record 10 of set 2 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=butaritari
# Processing record 11 of set 2 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=jamestown
# Processing record 12 of set 2 | Puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=puerto ayora
# Processing record 13 of set 2 | Cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=cockburn town
# Processing record 14 of set 2 | Ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=ribeira grande
# Processing record 15 of set 2 | Sovetskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=sovetskaya
# Processing record 16 of set 2 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=longyearbyen
# Processing record 17 of set 2 | Raga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=raga
# City not found!
# Processing record 18 of set 2 | Bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=bengkulu
# City not found!
# Processing record 19 of set 2 | Mandurah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=mandurah
# Processing record 20 of set 2 | Tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=tiznit
# Processing record 21 of set 2 | Nabinagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=nabinagar
# Processing record 22 of set 2 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=caravelas
# Processing record 23 of set 2 | Saint-joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=saint-joseph
# Processing record 24 of set 2 | Port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=port hardy
# Processing record 25 of set 2 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=kruisfontein
# Processing record 26 of set 2 | Arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=arraial do cabo
# Processing record 27 of set 2 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=bethel
# Processing record 28 of set 2 | Amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=amderma
# City not found!
# Processing record 29 of set 2 | Spirit river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=spirit river
# Processing record 30 of set 2 | Ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=ixtapa
# Processing record 31 of set 2 | Honningsvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=honningsvag
# Processing record 32 of set 2 | Namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=namibe
# Processing record 33 of set 2 | Guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=guerrero negro
# Processing record 34 of set 2 | Kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=kaeo
# Processing record 35 of set 2 | Bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=bambous virieux
# Processing record 36 of set 2 | Ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=ambilobe
# Processing record 37 of set 2 | Aasiaat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=aasiaat
# Processing record 38 of set 2 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=katsuura
# Processing record 39 of set 2 | Temaraia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=temaraia
# City not found!
# Processing record 40 of set 2 | Goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=goderich
# Processing record 41 of set 2 | Karakendzha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=karakendzha
# City not found!
# Processing record 42 of set 2 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=mataura
# Processing record 43 of set 2 | Arboletes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=arboletes
# Processing record 44 of set 2 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=aklavik
# Processing record 45 of set 2 | Punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=punta arenas
# Processing record 46 of set 2 | Voh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=voh
# Processing record 47 of set 2 | Nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=nizhneyansk
# City not found!
# Processing record 48 of set 2 | Hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=hami
# Processing record 49 of set 2 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=bredasdorp
# Processing record 50 of set 2 | Haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=haines junction
# Processing record 1 of set 3 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=lebu
# Processing record 2 of set 3 | Grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=grand river south east
# City not found!
# Processing record 3 of set 3 | Galveston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=galveston
# Processing record 4 of set 3 | Illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=illoqqortoormiut
# City not found!
# Processing record 5 of set 3 | Severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=severo-kurilsk
# Processing record 6 of set 3 | Soyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=soyo
# Processing record 7 of set 3 | Penzance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=penzance
# Processing record 8 of set 3 | Killybegs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=killybegs
# Processing record 9 of set 3 | Barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=barentsburg
# City not found!
# Processing record 10 of set 3 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=khatanga
# Processing record 11 of set 3 | Port ellen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=port ellen
# City not found!
# Processing record 12 of set 3 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=tuktoyaktuk
# Processing record 13 of set 3 | Samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=samusu
# City not found!
# Processing record 14 of set 3 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=iqaluit
# Processing record 15 of set 3 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=barrow
# Processing record 16 of set 3 | Trat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=trat
# Processing record 17 of set 3 | Necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=necochea
# Processing record 18 of set 3 | Sioux lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=sioux lookout
# Processing record 19 of set 3 | Martapura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=martapura
# Processing record 20 of set 3 | Kokopo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=kokopo
# Processing record 21 of set 3 | Moyale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=moyale
# Processing record 22 of set 3 | Punta de piedra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=punta de piedra
# Processing record 23 of set 3 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=qaanaaq
# Processing record 24 of set 3 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=provideniya
# Processing record 25 of set 3 | Cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=cabo san lucas
# Processing record 26 of set 3 | Bodden town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=bodden town
# Processing record 27 of set 3 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=chuy
# Processing record 28 of set 3 | Hermiston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=hermiston
# Processing record 29 of set 3 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=thompson
# Processing record 30 of set 3 | Karacakoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=karacakoy
# Processing record 31 of set 3 | Saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=saint-philippe
# Processing record 32 of set 3 | Victor harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=victor harbor
# Processing record 33 of set 3 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=nanortalik
# Processing record 34 of set 3 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=hithadhoo
# Processing record 35 of set 3 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=dikson
# Processing record 36 of set 3 | Vizinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=vizinga
# Processing record 37 of set 3 | Hastings
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=hastings
# Processing record 38 of set 3 | Shirpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=shirpur
# Processing record 39 of set 3 | Saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=saint george
# Processing record 40 of set 3 | Bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=bonavista
# Processing record 41 of set 3 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=tasiilaq
# Processing record 42 of set 3 | Nyon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=nyon
# Processing record 43 of set 3 | Umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=umzimvubu
# City not found!
# Processing record 44 of set 3 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=bathsheba
# Processing record 45 of set 3 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=victoria
# Processing record 46 of set 3 | Umm kaddadah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=umm kaddadah
# Processing record 47 of set 3 | Roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=roald
# Processing record 48 of set 3 | Vagay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=vagay
# Processing record 49 of set 3 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=lavrentiya
# Processing record 50 of set 3 | Farmington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=farmington
# Processing record 1 of set 4 | Lensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=lensk
# Processing record 2 of set 4 | Shelburne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=shelburne
# Processing record 3 of set 4 | Ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=ponta do sol
# Processing record 4 of set 4 | Dubti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=dubti
# Processing record 5 of set 4 | Linxia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=linxia
# Processing record 6 of set 4 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=yellowknife
# Processing record 7 of set 4 | Butte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=butte
# Processing record 8 of set 4 | Kachikau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=kachikau
# City not found!
# Processing record 9 of set 4 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=touros
# Processing record 10 of set 4 | Clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=clyde river
# Processing record 11 of set 4 | Puyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=puyang
# Processing record 12 of set 4 | Kasongo-lunda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=kasongo-lunda
# Processing record 13 of set 4 | Nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=nuuk
# Processing record 14 of set 4 | Loiza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=loiza
# Processing record 15 of set 4 | Nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=nouadhibou
# Processing record 16 of set 4 | Ossora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=ossora
# Processing record 17 of set 4 | Cheney
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=cheney
# Processing record 18 of set 4 | Havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=havoysund
# Processing record 19 of set 4 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=lagoa
# Processing record 20 of set 4 | Murud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=murud
# City not found!
# Processing record 21 of set 4 | Sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=sola
# Processing record 22 of set 4 | Springville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=springville
# Processing record 23 of set 4 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=isangel
# Processing record 24 of set 4 | Twentynine palms
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=twentynine palms
# Processing record 25 of set 4 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=naze
# Processing record 26 of set 4 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=georgetown
# Processing record 27 of set 4 | Waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=waipawa
# Processing record 28 of set 4 | Ust-ishim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=ust-ishim
# Processing record 29 of set 4 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=torbay
# Processing record 30 of set 4 | Maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=maragogi
# Processing record 31 of set 4 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=nome
# Processing record 32 of set 4 | Takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=takoradi
# Processing record 33 of set 4 | Viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=viedma
# Processing record 34 of set 4 | Gornopravdinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=gornopravdinsk
# Processing record 35 of set 4 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=ahipara
# Processing record 36 of set 4 | Qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=qasigiannguit
# Processing record 37 of set 4 | Fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=fort nelson
# Processing record 38 of set 4 | Evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=evensk
# Processing record 39 of set 4 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=tiksi
# Processing record 40 of set 4 | Maksatikha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=maksatikha
# Processing record 41 of set 4 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=geraldton
# Processing record 42 of set 4 | Tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=tautira
# Processing record 43 of set 4 | Burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=burnie
# Processing record 44 of set 4 | Matay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=matay
# Processing record 45 of set 4 | Te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=te anau
# Processing record 46 of set 4 | Weinan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=weinan
# Processing record 47 of set 4 | Culebra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=culebra
# Processing record 48 of set 4 | We
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=we
# City not found!
# Processing record 49 of set 4 | The pas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=the pas
# Processing record 50 of set 4 | Saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=saint-pierre
# Processing record 1 of set 5 | Kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=kalmunai
# Processing record 2 of set 5 | Ngunguru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=ngunguru
# Processing record 3 of set 5 | Halalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=halalo
# City not found!
# Processing record 4 of set 5 | Khuzhir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=khuzhir
# Processing record 5 of set 5 | Boyolangu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=boyolangu
# Processing record 6 of set 5 | Mayskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=mayskiy
# Processing record 7 of set 5 | Bajram curri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=bajram curri
# Processing record 8 of set 5 | Markova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=markova
# Processing record 9 of set 5 | Attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=attawapiskat
# City not found!
# Processing record 10 of set 5 | Tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=tessalit
# Processing record 11 of set 5 | Sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=sinnamary
# Processing record 12 of set 5 | Boende
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=boende
# Processing record 13 of set 5 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=sitka
# Processing record 14 of set 5 | Pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=pacific grove
# Processing record 15 of set 5 | Omaruru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=omaruru
# Processing record 16 of set 5 | General pico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=general pico
# Processing record 17 of set 5 | Carauari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=carauari
# Processing record 18 of set 5 | Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=pierre
# Processing record 19 of set 5 | Ino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=ino
# Processing record 20 of set 5 | Rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=rocha
# Processing record 21 of set 5 | Banda aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=banda aceh
# Processing record 22 of set 5 | Sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=sao filipe
# Processing record 23 of set 5 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=kahului
# Processing record 24 of set 5 | Lazurne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=lazurne
# Processing record 25 of set 5 | Bara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=bara
# Processing record 26 of set 5 | Motygino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=motygino
# Processing record 27 of set 5 | Samalaeulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=samalaeulu
# City not found!
# Processing record 28 of set 5 | Le port
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=le port
# Processing record 29 of set 5 | Maningrida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=maningrida
# Processing record 30 of set 5 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=kaitangata
# Processing record 31 of set 5 | Kenora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=kenora
# Processing record 32 of set 5 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=klaksvik
# Processing record 33 of set 5 | Bagdarin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=bagdarin
# Processing record 34 of set 5 | Salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=salinopolis
# Processing record 35 of set 5 | Uyuni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=uyuni
# Processing record 36 of set 5 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=upernavik
# Processing record 37 of set 5 | Mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=mys shmidta
# City not found!
# Processing record 38 of set 5 | Pella
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=pella
# Processing record 39 of set 5 | Qeshm
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=qeshm
# Processing record 40 of set 5 | Turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=turukhansk
# Processing record 41 of set 5 | Oga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=oga
# Processing record 42 of set 5 | Huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=huarmey
# Processing record 43 of set 5 | Tuggurt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=tuggurt
# City not found!
# Processing record 44 of set 5 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=leningradskiy
# Processing record 45 of set 5 | Luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=luanda
# Processing record 46 of set 5 | Guangyuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=guangyuan
# Processing record 47 of set 5 | Millau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=millau
# Processing record 48 of set 5 | Sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=sentyabrskiy
# City not found!
# Processing record 49 of set 5 | Ippy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=ippy
# Processing record 50 of set 5 | Khash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=khash
# Processing record 1 of set 6 | Barra patuca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=barra patuca
# Processing record 2 of set 6 | Varhaug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=varhaug
# Processing record 3 of set 6 | Qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=qaqortoq
# Processing record 4 of set 6 | Khandyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=khandyga
# Processing record 5 of set 6 | Nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=nemuro
# Processing record 6 of set 6 | Buin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=buin
# Processing record 7 of set 6 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=husavik
# Processing record 8 of set 6 | Adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=adrar
# Processing record 9 of set 6 | Price
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=price
# Processing record 10 of set 6 | Stornoway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=stornoway
# City not found!
# Processing record 11 of set 6 | Yuzhno-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=yuzhno-yeniseyskiy
# City not found!
# Processing record 12 of set 6 | Sao felix do xingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=sao felix do xingu
# Processing record 13 of set 6 | Puerto cabezas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=puerto cabezas
# Processing record 14 of set 6 | Bangui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=bangui
# Processing record 15 of set 6 | Palmares do sul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=palmares do sul
# Processing record 16 of set 6 | Karaul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=karaul
# City not found!
# Processing record 17 of set 6 | Negombo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=negombo
# Processing record 18 of set 6 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=kodiak
# Processing record 19 of set 6 | Inuvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=inuvik
# Processing record 20 of set 6 | Verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=verkhoyansk
# Processing record 21 of set 6 | Tateyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=tateyama
# Processing record 22 of set 6 | Namtsy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=namtsy
# Processing record 23 of set 6 | Sibirtsevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=sibirtsevo
# City not found!
# Processing record 24 of set 6 | Buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=buala
# Processing record 25 of set 6 | Sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=sechura
# Processing record 26 of set 6 | Cranbrook
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=cranbrook
# Processing record 27 of set 6 | Leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=leh
# Processing record 28 of set 6 | Urucara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=urucara
# Processing record 29 of set 6 | Mezen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=mezen
# Processing record 30 of set 6 | Alice town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=alice town
# Processing record 31 of set 6 | Margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=margate
# Processing record 32 of set 6 | Mauganj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=mauganj
# Processing record 33 of set 6 | Saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=saleaula
# City not found!
# Processing record 34 of set 6 | Sault sainte marie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=sault sainte marie
# Processing record 35 of set 6 | Girard
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=girard
# Processing record 36 of set 6 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=lorengau
# Processing record 37 of set 6 | Kremenki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=kremenki
# Processing record 38 of set 6 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=saldanha
# Processing record 39 of set 6 | Mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=mayo
# Processing record 40 of set 6 | Chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=chicama
# Processing record 41 of set 6 | Adamovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=adamovka
# Processing record 42 of set 6 | Jabinyanah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=jabinyanah
# Processing record 43 of set 6 | Rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=rawson
# Processing record 44 of set 6 | Chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=chapais
# Processing record 45 of set 6 | Xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=xining
# Processing record 46 of set 6 | Superior
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=superior
# Processing record 47 of set 6 | Vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=vostok
# Processing record 48 of set 6 | Hoa binh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=hoa binh
# Processing record 49 of set 6 | Port hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=port hedland
# Processing record 50 of set 6 | Karlstad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=karlstad
# Processing record 1 of set 7 | Tabiauea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=tabiauea
# City not found!
# Processing record 2 of set 7 | Marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=marzuq
# Processing record 3 of set 7 | Fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=fukue
# Processing record 4 of set 7 | Xai-xai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=xai-xai
# Processing record 5 of set 7 | Eenhana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=eenhana
# Processing record 6 of set 7 | Arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=arlit
# Processing record 7 of set 7 | Jacareacanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=jacareacanga
# Processing record 8 of set 7 | Udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=udachnyy
# Processing record 9 of set 7 | Algete
# ...
# Processing record 27 of set 11 | Zaysan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=zaysan
# Processing record 28 of set 11 | Yuanping
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=yuanping
# Processing record 29 of set 11 | Rosetta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=rosetta
# Processing record 30 of set 11 | Kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=kununurra
# Processing record 31 of set 11 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=namatanai
# Processing record 32 of set 11 | Kabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=kabo
# Processing record 33 of set 11 | Kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=kieta
# Processing record 34 of set 11 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=ilulissat
# Processing record 35 of set 11 | Mikuni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=mikuni
# Processing record 36 of set 11 | Sungaipenuh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=sungaipenuh
# Processing record 37 of set 11 | Mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=mount gambier
# Processing record 38 of set 11 | Labutta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=labutta
# City not found!
# Processing record 39 of set 11 | Mulchen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=mulchen
# Processing record 40 of set 11 | Yelizovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=yelizovo
# Processing record 41 of set 11 | Camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=camacha
# Processing record 42 of set 11 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=bubaque
# Processing record 43 of set 11 | La baule-escoublac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=la baule-escoublac
# Processing record 44 of set 11 | Itaqui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=itaqui
# Processing record 45 of set 11 | Ambon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=ambon
# Processing record 46 of set 11 | Aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=aksarka
# Processing record 47 of set 11 | Guanica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=guanica
# Processing record 48 of set 11 | Lakatoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=lakatoro
# Processing record 49 of set 11 | Ljungby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=ljungby
# Processing record 50 of set 11 | Riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=riyadh
# Processing record 1 of set 12 | Talcahuano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=talcahuano
# Processing record 2 of set 12 | Mao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=mao
# Processing record 3 of set 12 | Beeville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=beeville
# Processing record 4 of set 12 | Maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=maniitsoq
# Processing record 5 of set 12 | Gorontalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=gorontalo
# Processing record 6 of set 12 | Winfield
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=winfield
# Processing record 7 of set 12 | Kaihua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=kaihua
# Processing record 8 of set 12 | Tromso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=tromso
# Processing record 9 of set 12 | Snezhnogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=snezhnogorsk
# Processing record 10 of set 12 | Nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=nantucket
# Processing record 11 of set 12 | Cardston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=cardston
# Processing record 12 of set 12 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=hasaki
# Processing record 13 of set 12 | Gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=gat
# Processing record 14 of set 12 | Icod de los vinos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=icod de los vinos
# Processing record 15 of set 12 | Lodwar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=lodwar
# Processing record 16 of set 12 | Rundu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=rundu
# Processing record 17 of set 12 | Alihe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=alihe
# Processing record 18 of set 12 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=fortuna
# Processing record 19 of set 12 | Saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=saint-augustin
# Processing record 20 of set 12 | Marystown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=marystown
# Processing record 21 of set 12 | Tucuma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=tucuma
# City not found!
# Processing record 22 of set 12 | Ahuimanu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=ahuimanu
# Processing record 23 of set 12 | Pinotepa nacional
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=pinotepa nacional
# City not found!
# Processing record 24 of set 12 | Old road
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=old road
# City not found!
# Processing record 25 of set 12 | Carupano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=carupano
# Processing record 26 of set 12 | Dehui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=dehui
# Processing record 27 of set 12 | Sheltozero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=sheltozero
# Processing record 28 of set 12 | Boksitogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=boksitogorsk
# Processing record 29 of set 12 | Jiamusi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=jiamusi
# Processing record 30 of set 12 | Port augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=port augusta
# Processing record 31 of set 12 | Pleasanton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=pleasanton
# Processing record 32 of set 12 | Yabrud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=yabrud
# Processing record 33 of set 12 | Tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=tual
# Processing record 34 of set 12 | Ushtobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=ushtobe
# Processing record 35 of set 12 | Gilgit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=gilgit
# Processing record 36 of set 12 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=alofi
# Processing record 37 of set 12 | Carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=carutapera
# Processing record 38 of set 12 | Urdzhar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=urdzhar
# City not found!
# Processing record 39 of set 12 | Brownwood
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=brownwood
# Processing record 40 of set 12 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=airai
# Processing record 41 of set 12 | Flin flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=flin flon
# Processing record 42 of set 12 | Kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=kenai
# Processing record 43 of set 12 | Olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=olinda
# Processing record 44 of set 12 | Athabasca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=athabasca
# Processing record 45 of set 12 | Aguada de cima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=aguada de cima
# Processing record 46 of set 12 | Lokosovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=lokosovo
# Processing record 47 of set 12 | Berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=berlevag
# Processing record 48 of set 12 | Samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=samarai
# Processing record 49 of set 12 | Svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=svetlogorsk
# Processing record 50 of set 12 | Faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=faya
# Processing record 1 of set 13 | Ust-nera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=ust-nera
# Processing record 2 of set 13 | Caracoli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=caracoli
# Processing record 3 of set 13 | Rosarito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=rosarito
# Processing record 4 of set 13 | Dubai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=dubai
# Processing record 5 of set 13 | Kataysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=kataysk
# Processing record 6 of set 13 | Birao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=birao
# Processing record 7 of set 13 | Qui nhon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=qui nhon
# City not found!
# Processing record 8 of set 13 | Store heddinge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=store heddinge
# Processing record 9 of set 13 | Dzhusaly
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=dzhusaly
# City not found!
# Processing record 10 of set 13 | Zhoucheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=zhoucheng
# Processing record 11 of set 13 | Keuruu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=keuruu
# Processing record 12 of set 13 | Ajaccio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=ajaccio
# Processing record 13 of set 13 | Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=komsomolskiy
# Processing record 14 of set 13 | Booue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=booue
# Processing record 15 of set 13 | Kapoeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=kapoeta
# City not found!
# Processing record 16 of set 13 | Pouso alegre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=pouso alegre
# Processing record 17 of set 13 | Loding
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=loding
# Processing record 18 of set 13 | Rawannawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=rawannawi
# City not found!
# Processing record 19 of set 13 | Lugovoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=lugovoy
# Processing record 20 of set 13 | Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=vestmannaeyjar
# Processing record 21 of set 13 | Deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=deputatskiy
# Processing record 22 of set 13 | Hihifo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=hihifo
# City not found!
# Processing record 23 of set 13 | Jumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=jumla
# Processing record 24 of set 13 | Avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=avera
# Processing record 25 of set 13 | Chukhloma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=chukhloma
# Processing record 26 of set 13 | Port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=port lincoln
# Processing record 27 of set 13 | Christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=christchurch
# Processing record 28 of set 13 | Salym
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=7cf0bb5458a870743b2b6578cfcc1f3d&q=salym
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a data frame from cities, temp, humidity, cloudiness and wind speed
weather_dict = {
    "City": new_cities,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Temp": temp,
    "Lat" : lat,
    "Lng" : lng,   
    "Wind Speed" : wind
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#          City  Cloudiness Country        Date  Humidity   Temp    Lat     Lng  \
# 0       bluff          15      AU  1573361481         9  89.69 -23.58  149.07
# 1      sivaki         100      RU  1573361481        92  17.35  52.63  126.75
# 2    souillac          37      FR  1573361481        87  42.80  45.60   -0.60
# 3  chokurdakh          71      RU  1573361396        96  -2.87  70.62  147.90
# 4   busselton          15      AU  1573361482        35  82.00 -33.64  115.35
#
#    Wind Speed
# 0        2.98
# 1       10.92
# 2        3.36
# 3        5.46
# 4       12.41

# %%
# Changing time stamp to date time format
#Capitalize city name
weather_data["Date"]=pd.to_datetime(weather_data["Date"], unit='s')
weather_data["City"]= weather_data["City"].str.capitalize()


weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 565 entries, 0 to 564
# Data columns (total 9 columns):
# City          565 non-null object
# Cloudiness    565 non-null int64
# Country       565 non-null object
# Date          565 non-null datetime64[ns]
# Humidity      565 non-null int64
# Temp          565 non-null float64
# Lat           565 non-null float64
# Lng           565 non-null float64
# Wind Speed    565 non-null float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(2)
# memory usage: 39.9+ KB

# %%
# Export the city data into a .csv file
weather_data.to_csv(output_data_file)

#Display dataframe
weather_data.head()
# Out:
#          City  Cloudiness Country                Date  Humidity   Temp    Lat  \
# 0       Bluff          15      AU 2019-11-10 04:51:21         9  89.69 -23.58
# 1      Sivaki         100      RU 2019-11-10 04:51:21        92  17.35  52.63
# 2    Souillac          37      FR 2019-11-10 04:51:21        87  42.80  45.60
# 3  Chokurdakh          71      RU 2019-11-10 04:49:56        96  -2.87  70.62
# 4   Busselton          15      AU 2019-11-10 04:51:22        35  82.00 -33.64
#
#       Lng  Wind Speed
# 0  149.07        2.98
# 1  126.75       10.92
# 2   -0.60        3.36
# 3  147.90        5.46
# 4  115.35       12.41

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
#Checking global distribution of cities
#If distribution is not good re-generate random cities for avoiding data bias due to limited geographical spead of cities

fig, ax = plt.subplots()
ax.scatter(weather_data['Lng'], weather_data['Lat'],marker='*',color='green', alpha = 0.5,label="Cities")

#for the current time to be printed in the map
date_time = datetime.datetime.now()

ax.set_title(" Cities Analyzed \n{}".format(date_time.strftime("%x, %H:%M")))
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
plt.legend(loc='lower left')
plt.grid()
plt.show()

plt.savefig("Map_city_distribution.png")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
#For report gradient color bar based on attribute(temperature, Humidy, Windspeed) has been used
fig, axy = plt.subplots()
s=axy.scatter(weather_data['Lng'], weather_data['Lat'],c=weather_data['Temp'],marker='*', alpha = 0.5,label="Cities")
cb = plt.colorbar(s)
cb.set_label('Temperature')

#for the current time to be printed in the map
date_time = datetime.datetime.now()

axy.set_title(" Cities Analyzed \n{}".format(date_time.strftime("%x, %H:%M")))
axy.set_xlabel('Longitude')
axy.set_ylabel('Latitude')
plt.legend(loc='lower left')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# Latitude vs. Temperature Plot

# %%
#Plot 2
fig, ay = plt.subplots()
date_time = datetime.datetime.now()
#N=len(new_cities)
#colors = np.random.rand(N)
ay.scatter(weather_data['Lat'], weather_data['Temp'],marker='^',color='red', alpha = 0.25)

ay.set_title(" Temperature of Cities Analyzed,\n{}" .format(date_time.strftime("%x, %H:%M")))
ay.set_xlabel("South<---Latitude--->North")
ay.set_ylabel("Maximum Temperature (F)")
ay.set_xlim(-90,90)
ay.set_ylim(-30,130)
plt.grid()
plt.show()

plt.savefig("Temp_distribution.png")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# Latitude vs. Humidity Plot

# %%
fig, az=  plt.subplots()

date_time = datetime.datetime.now()

az.scatter(weather_data['Lat'], weather_data['Humidity'],marker='o', color="orange", alpha = 0.5)
az.set_title(" Humidity of Cities Analyzed, \n{}" .format(date_time.strftime("%x, %H:%M")))
az.set_xlabel("South<---Latitude--->North")
az.set_ylabel("Humidity (%)")
az.set_xlim(-90,90)
az.set_ylim(0-5,100+5)
plt.grid()
plt.show()

plt.savefig("Humidity_distribution.png")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig, ax1 = plt.subplots()
ax1.scatter(weather_data['Lat'], weather_data['Cloudiness'], marker='*',color='black',label="Cities")

#for the current time to be printed in the map
date_time = datetime.datetime.now()

ax1.set_title("Cloudiness of Cities Analyzed \n{}".format(date_time.strftime("%x, %H:%M")))
ax1.set_xlabel('South<---Latitude--->North')
ax1.set_ylabel('Cloudiness (%)')
ax1.set_xlim(-90,90)
ax1.set_ylim(0-5,100+5)
plt.grid()
plt.show()

plt.show()

plt.savefig("Cloudiness_distribution.png")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig, ax2 = plt.subplots()
ax2.scatter(weather_data['Lat'], weather_data['Wind Speed'], marker='*',color='purple',label="Cities")

#for the current time to be printed in the map
date_time = datetime.datetime.now()

ax2.set_title("Windspeed of Cities Analyzed \n{}".format(date_time.strftime("%x, %H:%M")))
ax2.set_xlabel('South<---Latitude--->North')
ax2.set_ylabel('Wind Speed (mph)')
ax2.set_xlim(-90,90)
ax2.set_ylim(0-5,50)
plt.grid()
plt.show()

plt.savefig("Windspeed_distribution.png")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
